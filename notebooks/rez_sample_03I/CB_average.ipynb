# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_03ALL/buildtime_dc2.csv')

df
# Out:
#          Branch                                             Option  bt_real  \
# 0   xterm-00001  ['--disable-ansi-color', '--disable-256-color'...   8.6040
# 1   xterm-00002  ['--disable-ansi-color', '--disable-direct-col...   8.2440
# 2   xterm-00003  ['--disable-ansi-color', '--disable-direct-col...  11.6390
# 3   xterm-00004  ['--disable-ansi-color', '--disable-direct-col...  11.3290
# 4   xterm-00005  ['--disable-16-color', '--disable-256-color', ...  11.8175
# 5   xterm-00006  ['--disable-ansi-color', '--disable-16-color',...  10.2265
# 6   xterm-00007  ['--disable-ansi-color', '--disable-16-color',...   9.7415
# 7   xterm-00008  ['--disable-active-icon', '--disable-ansi-colo...   9.9600
# 8   xterm-00009  ['--disable-ansi-color', '--disable-bold-color...  11.5310
# 9   xterm-00010  ['--disable-active-icon', '--disable-16-color'...  10.7720
# 10  xterm-00011  ['--disable-active-icon', '--disable-16-color'...   9.8925
# 11  xterm-00012  ['--disable-active-icon', '--disable-ansi-colo...   9.0840
# 12  xterm-00013  ['--disable-active-icon', '--disable-16-color'...  10.1660
# 13  xterm-00014  ['--disable-ansi-color', '--disable-256-color'...   8.9135
# 14  xterm-00015  ['--disable-active-icon', '--disable-16-color'...  10.2610
# 15  xterm-00016  ['--disable-ansi-color', '--disable-direct-col...   9.8295
# 16  xterm-00017  ['--disable-16-color', '--disable-256-color', ...   7.6720
# 17  xterm-00018  ['--disable-active-icon', '--disable-16-color'...   8.6340
# 18  xterm-00019  ['--disable-ansi-color', '--disable-blink-curs...  11.8460
# 19  xterm-00020  ['--disable-ansi-color', '--disable-16-color',...  10.9115
#
#     BinarySize
# 0      2736120
# 1      2468160
# 2      3202648
# 3      3344192
# 4      3456200
# 5      3015768
# 6      2857160
# 7      2902288
# 8      3218472
# 9      3023648
# 10     2904408
# 11     2883584
# 12     3015848
# 13     2743048
# 14     3057856
# 15     2862200
# 16     2393760
# 17     2739752
# 18     3295512
# 19     3034008

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_03ALL/buildtime_di1.csv')

df
# Out:
#                  Branch                                             Option  \
# 0    ixterm-00001-00002  ['--disable-ansi-color', '--disable-direct-col...
# 1    ixterm-00001-00003  ['--disable-ansi-color', '--disable-direct-col...
# 2    ixterm-00001-00004  ['--disable-ansi-color', '--disable-direct-col...
# 3    ixterm-00001-00005  ['--disable-16-color', '--disable-256-color', ...
# 4    ixterm-00001-00006  ['--disable-ansi-color', '--disable-16-color',...
# ..                  ...                                                ...
# 375  ixterm-00020-00015  ['--disable-active-icon', '--disable-16-color'...
# 376  ixterm-00020-00016  ['--disable-ansi-color', '--disable-direct-col...
# 377  ixterm-00020-00017  ['--disable-16-color', '--disable-256-color', ...
# 378  ixterm-00020-00018  ['--disable-active-icon', '--disable-16-color'...
# 379  ixterm-00020-00019  ['--disable-ansi-color', '--disable-blink-curs...
#
#      bt_real  BinarySize
# 0     8.0595     2468160
# 1    11.4715     3202648
# 2    11.1620     3344192
# 3    11.6775     3456200
# 4     9.9710     3015768
# ..       ...         ...
# 375  10.1740     3057856
# 376   9.6670     2862200
# 377   7.5530     2393760
# 378   8.5090     2739752
# 379  11.6935     3295512
#
# [380 rows x 4 columns]
