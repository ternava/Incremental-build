# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}) #.reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_03ALL/buildtime_dc2.csv')

df
# Out:
#                                                                  bt_real  \
# Branch       Option
# sqlite-00001 ['--disable-shared', '--disable-tcl', '--disabl...  61.0735
# sqlite-00002 ['--disable-shared', '--disable-option-checking...  65.6735
# sqlite-00003 ['--disable-shared', '--disable-largefile', '--...  68.3485
# sqlite-00004 ['--disable-shared', '--disable-option-checking...  68.6350
# sqlite-00005 ['--disable-shared', '--disable-amalgamation', ...  68.5450
# sqlite-00006 ['--disable-shared', '--disable-largefile', '--...  72.6415
# sqlite-00007 ['--disable-shared', '--disable-libtool-lock', ...  57.0845
# sqlite-00008 ['--disable-shared', '--disable-option-checking...  59.4100
# sqlite-00009 ['--disable-shared', '--disable-option-checking...  72.5755
# sqlite-00010 ['--disable-shared', '--disable-largefile', '--...  71.3555
# sqlite-00011 ['--disable-shared', '--disable-readline', '--e...  68.1140
# sqlite-00012 ['--disable-shared', '--disable-libtool-lock', ...  68.5725
# sqlite-00013 ['--disable-shared', '--disable-largefile', '--...  54.4455
# sqlite-00014 ['--disable-shared', '--disable-option-checking...  70.8165
# sqlite-00015 ['--disable-shared', '--disable-largefile', '--...  62.4900
# sqlite-00016 ['--disable-shared', '--disable-libtool-lock', ...  65.9810
# sqlite-00017 ['--disable-shared', '--disable-threadsafe', '-...  67.8495
# sqlite-00018 ['--disable-shared', '--disable-libtool-lock', ...  58.8655
# sqlite-00019 ['--disable-shared', '--disable-option-checking...  72.4330
# sqlite-00020 ['--disable-shared', '--disable-threadsafe', '-...  70.9070
#
#                                                                  BinarySize
# Branch       Option
# sqlite-00001 ['--disable-shared', '--disable-tcl', '--disabl...     9648880
# sqlite-00002 ['--disable-shared', '--disable-option-checking...    10173424
# sqlite-00003 ['--disable-shared', '--disable-largefile', '--...     9699272
# sqlite-00004 ['--disable-shared', '--disable-option-checking...    10199640
# sqlite-00005 ['--disable-shared', '--disable-amalgamation', ...    10147616
# sqlite-00006 ['--disable-shared', '--disable-largefile', '--...    10201208
# sqlite-00007 ['--disable-shared', '--disable-libtool-lock', ...     8464736
# sqlite-00008 ['--disable-shared', '--disable-option-checking...     8528944
# sqlite-00009 ['--disable-shared', '--disable-option-checking...    10190120
# sqlite-00010 ['--disable-shared', '--disable-largefile', '--...    10106296
# sqlite-00011 ['--disable-shared', '--disable-readline', '--e...    10215824
# sqlite-00012 ['--disable-shared', '--disable-libtool-lock', ...    10147616
# sqlite-00013 ['--disable-shared', '--disable-largefile', '--...     8566104
# sqlite-00014 ['--disable-shared', '--disable-option-checking...    10075160
# sqlite-00015 ['--disable-shared', '--disable-largefile', '--...     8960648
# sqlite-00016 ['--disable-shared', '--disable-libtool-lock', ...     9986640
# sqlite-00017 ['--disable-shared', '--disable-threadsafe', '-...    10123416
# sqlite-00018 ['--disable-shared', '--disable-libtool-lock', ...     8656016
# sqlite-00019 ['--disable-shared', '--disable-option-checking...    10203840
# sqlite-00020 ['--disable-shared', '--disable-threadsafe', '-...    10084648

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}) #.reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_03ALL/buildtime_di1.csv')

df
# Out:
#                                                                         bt_real  \
# Branch              Option
# isqlite-00001-00002 ['--disable-shared', '--disable-option-checking...   0.0110
# isqlite-00001-00003 ['--disable-shared', '--disable-largefile', '--...  30.2950
# isqlite-00001-00004 ['--disable-shared', '--disable-option-checking...   0.0110
# isqlite-00001-00005 ['--disable-shared', '--disable-amalgamation', ...   0.0115
# isqlite-00001-00006 ['--disable-shared', '--disable-largefile', '--...  70.2090
# ...                                                                         ...
# isqlite-00020-00015 ['--disable-shared', '--disable-largefile', '--...   0.0100
# isqlite-00020-00016 ['--disable-shared', '--disable-libtool-lock', ...  27.6225
# isqlite-00020-00017 ['--disable-shared', '--disable-threadsafe', '-...  29.1355
# isqlite-00020-00018 ['--disable-shared', '--disable-libtool-lock', ...  24.9405
# isqlite-00020-00019 ['--disable-shared', '--disable-option-checking...   0.0090
#
#                                                                         BinarySize
# Branch              Option
# isqlite-00001-00002 ['--disable-shared', '--disable-option-checking...     9648880
# isqlite-00001-00003 ['--disable-shared', '--disable-largefile', '--...     9648880
# isqlite-00001-00004 ['--disable-shared', '--disable-option-checking...     9648880
# isqlite-00001-00005 ['--disable-shared', '--disable-amalgamation', ...     9648880
# isqlite-00001-00006 ['--disable-shared', '--disable-largefile', '--...    10190888
# ...                                                                            ...
# isqlite-00020-00015 ['--disable-shared', '--disable-largefile', '--...    10084648
# isqlite-00020-00016 ['--disable-shared', '--disable-libtool-lock', ...    10084648
# isqlite-00020-00017 ['--disable-shared', '--disable-threadsafe', '-...    10084648
# isqlite-00020-00018 ['--disable-shared', '--disable-libtool-lock', ...    10084648
# isqlite-00020-00019 ['--disable-shared', '--disable-option-checking...    10084648
#
# [380 rows x 2 columns]
