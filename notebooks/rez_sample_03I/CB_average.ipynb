# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}) #.reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_03ALL/buildtime_dc2.csv')

df
# Out:
#                                                              bt_real  \
# Branch   Option
# xz-00001 ['--enable-debug', '--enable-encoders=lzma1', '...  12.1465
# xz-00002 ['--enable-encoders=lzma1,lzma2', '--enable-dec...  10.7755
# xz-00003 ['--enable-debug', '--enable-encoders=lzma1,lzm...  11.3905
# xz-00004 ['--enable-debug', '--enable-encoders=lzma1,pow...  10.5150
# xz-00005 ['--enable-debug', '--enable-encoders=lzma1,ia6...  10.2415
# xz-00006 ['--enable-debug', '--enable-encoders=lzma1,pow...  10.3715
# xz-00007 ['--enable-encoders=lzma1,delta', '--enable-dec...  11.1995
# xz-00008 ['--enable-encoders=lzma1,armthumb', '--enable-...  11.8850
# xz-00009 ['--enable-debug', '--enable-encoders=lzma1,arm...  11.2410
# xz-00010 ['--enable-encoders=lzma1,powerpc', '--enable-d...  10.5855
# xz-00011 ['--enable-debug', '--enable-encoders=lzma1,del...  10.2945
# xz-00012 ['--enable-debug', '--enable-encoders=lzma1,arm...  10.1955
# xz-00013 ['--enable-debug', '--enable-encoders=lzma1,spa...  10.5795
# xz-00014 ['--enable-encoders=lzma1,powerpc', '--enable-d...  10.4410
# xz-00015 ['--enable-encoders=lzma1,arm', '--enable-decod...  10.5300
# xz-00016 ['--enable-debug', '--enable-encoders=lzma1,lzm...  12.4550
# xz-00017 ['--enable-encoders=lzma1,powerpc', '--enable-d...  10.5275
# xz-00018 ['--enable-encoders=lzma1,lzma2', '--enable-dec...  11.1715
# xz-00019 ['--enable-debug', '--enable-encoders=lzma1,arm...  11.5855
# xz-00020 ['--enable-encoders=lzma1,delta', '--enable-dec...  10.1900
#
#                                                              BinarySize
# Branch   Option
# xz-00001 ['--enable-debug', '--enable-encoders=lzma1', '...     1215672
# xz-00002 ['--enable-encoders=lzma1,lzma2', '--enable-dec...     1072480
# xz-00003 ['--enable-debug', '--enable-encoders=lzma1,lzm...     1209072
# xz-00004 ['--enable-debug', '--enable-encoders=lzma1,pow...     1064448
# xz-00005 ['--enable-debug', '--enable-encoders=lzma1,ia6...     1067256
# xz-00006 ['--enable-debug', '--enable-encoders=lzma1,pow...     1108144
# xz-00007 ['--enable-encoders=lzma1,delta', '--enable-dec...     1145960
# xz-00008 ['--enable-encoders=lzma1,armthumb', '--enable-...     1180656
# xz-00009 ['--enable-debug', '--enable-encoders=lzma1,arm...     1153072
# xz-00010 ['--enable-encoders=lzma1,powerpc', '--enable-d...     1005216
# xz-00011 ['--enable-debug', '--enable-encoders=lzma1,del...     1050248
# xz-00012 ['--enable-debug', '--enable-encoders=lzma1,arm...     1037416
# xz-00013 ['--enable-debug', '--enable-encoders=lzma1,spa...     1067432
# xz-00014 ['--enable-encoders=lzma1,powerpc', '--enable-d...     1140664
# xz-00015 ['--enable-encoders=lzma1,arm', '--enable-decod...     1092248
# xz-00016 ['--enable-debug', '--enable-encoders=lzma1,lzm...     1290136
# xz-00017 ['--enable-encoders=lzma1,powerpc', '--enable-d...     1005520
# xz-00018 ['--enable-encoders=lzma1,lzma2', '--enable-dec...     1080984
# xz-00019 ['--enable-debug', '--enable-encoders=lzma1,arm...     1216264
# xz-00020 ['--enable-encoders=lzma1,delta', '--enable-dec...     1058496

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}) #.reset_index()

#df = df.replace('-1.0', np.nan)
#df['BinarySize'] = df.BinarySize.str.replace('-1', 'NaN')

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_03ALL/buildtime_di1.csv')

df
# Out:
#                                                                     bt_real  \
# Branch          Option
# ixz-00001-00002 ['--enable-encoders=lzma1,lzma2', '--enable-dec...  10.9520
# ixz-00001-00003 ['--enable-debug', '--enable-encoders=lzma1,lzm...  -1.0000
# ixz-00001-00004 ['--enable-debug', '--enable-encoders=lzma1,pow...  11.3420
# ixz-00001-00005 ['--enable-debug', '--enable-encoders=lzma1,ia6...  -1.0000
# ixz-00001-00006 ['--enable-debug', '--enable-encoders=lzma1,pow...  -1.0000
# ...                                                                     ...
# ixz-00020-00015 ['--enable-encoders=lzma1,arm', '--enable-decod...  10.7795
# ixz-00020-00016 ['--enable-debug', '--enable-encoders=lzma1,lzm...  -1.0000
# ixz-00020-00017 ['--enable-encoders=lzma1,powerpc', '--enable-d...  -1.0000
# ixz-00020-00018 ['--enable-encoders=lzma1,lzma2', '--enable-dec...  10.6740
# ixz-00020-00019 ['--enable-debug', '--enable-encoders=lzma1,arm...  -1.0000
#
#                                                                     BinarySize
# Branch          Option
# ixz-00001-00002 ['--enable-encoders=lzma1,lzma2', '--enable-dec...     1072480
# ixz-00001-00003 ['--enable-debug', '--enable-encoders=lzma1,lzm...          -1
# ixz-00001-00004 ['--enable-debug', '--enable-encoders=lzma1,pow...     1064448
# ixz-00001-00005 ['--enable-debug', '--enable-encoders=lzma1,ia6...     1215672
# ixz-00001-00006 ['--enable-debug', '--enable-encoders=lzma1,pow...     1215672
# ...                                                                        ...
# ixz-00020-00015 ['--enable-encoders=lzma1,arm', '--enable-decod...     1092248
# ixz-00020-00016 ['--enable-debug', '--enable-encoders=lzma1,lzm...     1058496
# ixz-00020-00017 ['--enable-encoders=lzma1,powerpc', '--enable-d...          -1
# ixz-00020-00018 ['--enable-encoders=lzma1,lzma2', '--enable-dec...     1080984
# ixz-00020-00019 ['--enable-debug', '--enable-encoders=lzma1,arm...     1058496
#
# [380 rows x 2 columns]
