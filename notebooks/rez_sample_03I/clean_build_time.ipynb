# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_03I/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#           Branch                                             Option  \
# 0   sqlite-00006  ['--disable-shared', '--disable-largefile', '-...
# 1   sqlite-00015  ['--disable-shared', '--disable-largefile', '-...
# 2   sqlite-00012  ['--disable-shared', '--disable-libtool-lock',...
# 3   sqlite-00014  ['--disable-shared', '--disable-option-checkin...
# 4   sqlite-00005  ['--disable-shared', '--disable-amalgamation',...
# 5   sqlite-00020  ['--disable-shared', '--disable-threadsafe', '...
# 6   sqlite-00010  ['--disable-shared', '--disable-largefile', '-...
# 7   sqlite-00004  ['--disable-shared', '--disable-option-checkin...
# 8   sqlite-00007  ['--disable-shared', '--disable-libtool-lock',...
# 9   sqlite-00017  ['--disable-shared', '--disable-threadsafe', '...
# 10  sqlite-00008  ['--disable-shared', '--disable-option-checkin...
# 11  sqlite-00009  ['--disable-shared', '--disable-option-checkin...
# 12  sqlite-00019  ['--disable-shared', '--disable-option-checkin...
# 13  sqlite-00001  ['--disable-shared', '--disable-tcl', '--disab...
# 14  sqlite-00011  ['--disable-shared', '--disable-readline', '--...
# 15  sqlite-00016  ['--disable-shared', '--disable-libtool-lock',...
# 16  sqlite-00013  ['--disable-shared', '--disable-largefile', '-...
# 17  sqlite-00018  ['--disable-shared', '--disable-libtool-lock',...
# 18  sqlite-00003  ['--disable-shared', '--disable-largefile', '-...
# 19  sqlite-00002  ['--disable-shared', '--disable-option-checkin...
#
#     Build Time  bt_user  bt_sys  Binary Size
# 0       72.304   70.915   1.178     10201208
# 1       62.604   61.346   1.085      8960648
# 2       68.399   65.680   2.541     10147616
# 3       70.716   69.406   1.127     10075160
# 4       68.240   65.604   2.478     10147616
# 5       70.618   69.284   1.143     10084648
# 6       71.445   70.069   1.177     10106296
# 7       68.483   65.759   2.568     10199640
# 8       56.787   54.343   2.317      8464736
# 9       67.631   64.961   2.516     10123416
# 10      59.176   58.062   0.963      8528944
# 11      72.447   71.086   1.159     10190120
# 12      72.295   70.969   1.135     10203840
# 13      60.913   58.508   2.260      9648880
# 14      68.105   66.848   1.062     10215824
# 15      65.815   63.198   2.464      9986640
# 16      54.307   51.923   2.255      8566104
# 17      58.746   56.253   2.353      8656016
# 18      68.206   66.897   1.117      9699272
# 19      65.656   63.046   2.451     10173424

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001        60.913      9648880
# 00002        65.656     10173424
# 00003        68.206      9699272
# 00004        68.483     10199640
# 00005        68.240     10147616
# 00006        72.304     10201208
# 00007        56.787      8464736
# 00008        59.176      8528944
# 00009        72.447     10190120
# 00010        71.445     10106296
# 00011        68.105     10215824
# 00012        68.399     10147616
# 00013        54.307      8566104
# 00014        70.716     10075160
# 00015        62.604      8960648
# 00016        65.815      9986640
# 00017        67.631     10123416
# 00018        58.746      8656016
# 00019        72.295     10203840
# 00020        70.618     10084648
