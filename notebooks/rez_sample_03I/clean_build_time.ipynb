# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_03ALL/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#       Branch                                             Option  Build Time  \
# 0   xz-00001  ['--enable-debug', '--enable-encoders=lzma1', ...     12.1465
# 1   xz-00002  ['--enable-encoders=lzma1,lzma2', '--enable-de...     10.7755
# 2   xz-00003  ['--enable-debug', '--enable-encoders=lzma1,lz...     11.3905
# 3   xz-00004  ['--enable-debug', '--enable-encoders=lzma1,po...     10.5150
# 4   xz-00005  ['--enable-debug', '--enable-encoders=lzma1,ia...     10.2415
# 5   xz-00006  ['--enable-debug', '--enable-encoders=lzma1,po...     10.3715
# 6   xz-00007  ['--enable-encoders=lzma1,delta', '--enable-de...     11.1995
# 7   xz-00008  ['--enable-encoders=lzma1,armthumb', '--enable...     11.8850
# 8   xz-00009  ['--enable-debug', '--enable-encoders=lzma1,ar...     11.2410
# 9   xz-00010  ['--enable-encoders=lzma1,powerpc', '--enable-...     10.5855
# 10  xz-00011  ['--enable-debug', '--enable-encoders=lzma1,de...     10.2945
# 11  xz-00012  ['--enable-debug', '--enable-encoders=lzma1,ar...     10.1955
# 12  xz-00013  ['--enable-debug', '--enable-encoders=lzma1,sp...     10.5795
# 13  xz-00014  ['--enable-encoders=lzma1,powerpc', '--enable-...     10.4410
# 14  xz-00015  ['--enable-encoders=lzma1,arm', '--enable-deco...     10.5300
# 15  xz-00016  ['--enable-debug', '--enable-encoders=lzma1,lz...     12.4550
# 16  xz-00017  ['--enable-encoders=lzma1,powerpc', '--enable-...     10.5275
# 17  xz-00018  ['--enable-encoders=lzma1,lzma2', '--enable-de...     11.1715
# 18  xz-00019  ['--enable-debug', '--enable-encoders=lzma1,ar...     11.5855
# 19  xz-00020  ['--enable-encoders=lzma1,delta', '--enable-de...     10.1900
#
#     Binary Size
# 0       1215672
# 1       1072480
# 2       1209072
# 3       1064448
# 4       1067256
# 5       1108144
# 6       1145960
# 7       1180656
# 8       1153072
# 9       1005216
# 10      1050248
# 11      1037416
# 12      1067432
# 13      1140664
# 14      1092248
# 15      1290136
# 16      1005520
# 17      1080984
# 18      1216264
# 19      1058496

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001       12.1465      1215672
# 00002       10.7755      1072480
# 00003       11.3905      1209072
# 00004       10.5150      1064448
# 00005       10.2415      1067256
# 00006       10.3715      1108144
# 00007       11.1995      1145960
# 00008       11.8850      1180656
# 00009       11.2410      1153072
# 00010       10.5855      1005216
# 00011       10.2945      1050248
# 00012       10.1955      1037416
# 00013       10.5795      1067432
# 00014       10.4410      1140664
# 00015       10.5300      1092248
# 00016       12.4550      1290136
# 00017       10.5275      1005520
# 00018       11.1715      1080984
# 00019       11.5855      1216264
# 00020       10.1900      1058496
