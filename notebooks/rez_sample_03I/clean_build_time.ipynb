# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_03ALL/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#     Unnamed: 0      Branch                                             Option  \
# 0            0  curl-00001  ['--disable-shared', '--disable-largefile', '-...
# 1            1  curl-00002  ['--disable-shared', '--disable-largefile', '-...
# 2            2  curl-00003  ['--disable-shared', '--disable-largefile', '-...
# 3            3  curl-00004  ['--disable-shared', '--enable-silent-rules', ...
# 4            4  curl-00005  ['--disable-shared', '--disable-debug', '--dis...
# 5            5  curl-00006  ['--disable-shared', '--disable-silent-rules',...
# 6            6  curl-00007  ['--disable-shared', '--disable-silent-rules',...
# 7            7  curl-00008  ['--disable-shared', '--disable-largefile', '-...
# 8            8  curl-00009  ['--disable-shared', '--enable-silent-rules', ...
# 9            9  curl-00010  ['--disable-shared', '--enable-silent-rules', ...
# 10          10  curl-00011  ['--disable-shared', '--disable-silent-rules',...
# 11          11  curl-00012  ['--disable-shared', '--disable-largefile', '-...
# 12          12  curl-00013  ['--disable-shared', '--disable-largefile', '-...
# 13          13  curl-00014  ['--disable-shared', '--disable-largefile', '-...
# 14          14  curl-00015  ['--disable-shared', '--disable-largefile', '-...
# 15          15  curl-00016  ['--disable-shared', '--disable-largefile', '-...
# 16          16  curl-00017  ['--disable-shared', '--disable-largefile', '-...
# 17          17  curl-00018  ['--disable-shared', '--disable-largefile', '-...
# 18          18  curl-00019  ['--disable-shared', '--disable-debug', '--dis...
# 19          19  curl-00020  ['--disable-shared', '--enable-silent-rules', ...
#
#     Build Time  Binary Size
# 0      23.5600      4898824
# 1      42.4200      3669216
# 2      30.5205       644608
# 3      44.0210      4356640
# 4      24.9920      1067672
# 5      23.6060      4516392
# 6      22.9120      4292872
# 7      34.0505      4783008
# 8      29.3685       784552
# 9      24.0520      4521984
# 10     55.9795      4493712
# 11     26.1350       855600
# 12     40.8015      2741048
# 13     70.9485      4759672
# 14     41.0765      3637952
# 15     44.3765      4077664
# 16     29.3405      4670072
# 17     23.2600       723024
# 18     21.7170      1149776
# 19     56.8570      4208096

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001       23.5600      4898824
# 00002       42.4200      3669216
# 00003       30.5205       644608
# 00004       44.0210      4356640
# 00005       24.9920      1067672
# 00006       23.6060      4516392
# 00007       22.9120      4292872
# 00008       34.0505      4783008
# 00009       29.3685       784552
# 00010       24.0520      4521984
# 00011       55.9795      4493712
# 00012       26.1350       855600
# 00013       40.8015      2741048
# 00014       70.9485      4759672
# 00015       41.0765      3637952
# 00016       44.3765      4077664
# 00017       29.3405      4670072
# 00018       23.2600       723024
# 00019       21.7170      1149776
# 00020       56.8570      4208096
