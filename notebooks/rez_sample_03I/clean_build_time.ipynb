# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_03ALL/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#           Branch                                             Option  \
# 0   sqlite-00001  ['--disable-shared', '--disable-tcl', '--disab...
# 1   sqlite-00002  ['--disable-shared', '--disable-option-checkin...
# 2   sqlite-00003  ['--disable-shared', '--disable-largefile', '-...
# 3   sqlite-00004  ['--disable-shared', '--disable-option-checkin...
# 4   sqlite-00005  ['--disable-shared', '--disable-amalgamation',...
# 5   sqlite-00006  ['--disable-shared', '--disable-largefile', '-...
# 6   sqlite-00007  ['--disable-shared', '--disable-libtool-lock',...
# 7   sqlite-00008  ['--disable-shared', '--disable-option-checkin...
# 8   sqlite-00009  ['--disable-shared', '--disable-option-checkin...
# 9   sqlite-00010  ['--disable-shared', '--disable-largefile', '-...
# 10  sqlite-00011  ['--disable-shared', '--disable-readline', '--...
# 11  sqlite-00012  ['--disable-shared', '--disable-libtool-lock',...
# 12  sqlite-00013  ['--disable-shared', '--disable-largefile', '-...
# 13  sqlite-00014  ['--disable-shared', '--disable-option-checkin...
# 14  sqlite-00015  ['--disable-shared', '--disable-largefile', '-...
# 15  sqlite-00016  ['--disable-shared', '--disable-libtool-lock',...
# 16  sqlite-00017  ['--disable-shared', '--disable-threadsafe', '...
# 17  sqlite-00018  ['--disable-shared', '--disable-libtool-lock',...
# 18  sqlite-00019  ['--disable-shared', '--disable-option-checkin...
# 19  sqlite-00020  ['--disable-shared', '--disable-threadsafe', '...
#
#     Build Time  Binary Size
# 0      61.0735      9648880
# 1      65.6735     10173424
# 2      68.3485      9699272
# 3      68.6350     10199640
# 4      68.5450     10147616
# 5      72.6415     10201208
# 6      57.0845      8464736
# 7      59.4100      8528944
# 8      72.5755     10190120
# 9      71.3555     10106296
# 10     68.1140     10215824
# 11     68.5725     10147616
# 12     54.4455      8566104
# 13     70.8165     10075160
# 14     62.4900      8960648
# 15     65.9810      9986640
# 16     67.8495     10123416
# 17     58.8655      8656016
# 18     72.4330     10203840
# 19     70.9070     10084648

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001       61.0735      9648880
# 00002       65.6735     10173424
# 00003       68.3485      9699272
# 00004       68.6350     10199640
# 00005       68.5450     10147616
# 00006       72.6415     10201208
# 00007       57.0845      8464736
# 00008       59.4100      8528944
# 00009       72.5755     10190120
# 00010       71.3555     10106296
# 00011       68.1140     10215824
# 00012       68.5725     10147616
# 00013       54.4455      8566104
# 00014       70.8165     10075160
# 00015       62.4900      8960648
# 00016       65.9810      9986640
# 00017       67.8495     10123416
# 00018       58.8655      8656016
# 00019       72.4330     10203840
# 00020       70.9070     10084648
