# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd

# Find the average of clean Built Time (column "bt_real")
# and the average of Binary Size in both executions 

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved their average to a new CSV file

df.to_csv(path + 'rez_sample_03ALL/buildtime_dc2.csv')
df
# Out:
#           Branch                                             Option  bt_real  \
# 0   sqlite-00001  ['--disable-shared', '--disable-tcl', '--disab...  61.0735
# 1   sqlite-00002  ['--disable-shared', '--disable-option-checkin...  65.6735
# 2   sqlite-00003  ['--disable-shared', '--disable-largefile', '-...  68.3485
# 3   sqlite-00004  ['--disable-shared', '--disable-option-checkin...  68.6350
# 4   sqlite-00005  ['--disable-shared', '--disable-amalgamation',...  68.5450
# 5   sqlite-00006  ['--disable-shared', '--disable-largefile', '-...  72.6415
# 6   sqlite-00007  ['--disable-shared', '--disable-libtool-lock',...  57.0845
# 7   sqlite-00008  ['--disable-shared', '--disable-option-checkin...  59.4100
# 8   sqlite-00009  ['--disable-shared', '--disable-option-checkin...  72.5755
# 9   sqlite-00010  ['--disable-shared', '--disable-largefile', '-...  71.3555
# 10  sqlite-00011  ['--disable-shared', '--disable-readline', '--...  68.1140
# 11  sqlite-00012  ['--disable-shared', '--disable-libtool-lock',...  68.5725
# 12  sqlite-00013  ['--disable-shared', '--disable-largefile', '-...  54.4455
# 13  sqlite-00014  ['--disable-shared', '--disable-option-checkin...  70.8165
# 14  sqlite-00015  ['--disable-shared', '--disable-largefile', '-...  62.4900
# 15  sqlite-00016  ['--disable-shared', '--disable-libtool-lock',...  65.9810
# 16  sqlite-00017  ['--disable-shared', '--disable-threadsafe', '...  67.8495
# 17  sqlite-00018  ['--disable-shared', '--disable-libtool-lock',...  58.8655
# 18  sqlite-00019  ['--disable-shared', '--disable-option-checkin...  72.4330
# 19  sqlite-00020  ['--disable-shared', '--disable-threadsafe', '...  70.9070
#
#     BinarySize
# 0      9648880
# 1     10173424
# 2      9699272
# 3     10199640
# 4     10147616
# 5     10201208
# 6      8464736
# 7      8528944
# 8     10190120
# 9     10106296
# 10    10215824
# 11    10147616
# 12     8566104
# 13    10075160
# 14     8960648
# 15     9986640
# 16    10123416
# 17     8656016
# 18    10203840
# 19    10084648

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd

# Find the average of incremental Built Time (column "bt_real")
# and the average of Binary Size in both executions 

df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved their average to a new CSV file

df.to_csv(path + 'rez_sample_03ALL/buildtime_di1.csv')
df
# Out:
#                   Branch                                             Option  \
# 0    isqlite-00001-00002  ['--disable-shared', '--disable-option-checkin...
# 1    isqlite-00001-00003  ['--disable-shared', '--disable-largefile', '-...
# 2    isqlite-00001-00004  ['--disable-shared', '--disable-option-checkin...
# 3    isqlite-00001-00005  ['--disable-shared', '--disable-amalgamation',...
# 4    isqlite-00001-00006  ['--disable-shared', '--disable-largefile', '-...
# ..                   ...                                                ...
# 375  isqlite-00020-00015  ['--disable-shared', '--disable-largefile', '-...
# 376  isqlite-00020-00016  ['--disable-shared', '--disable-libtool-lock',...
# 377  isqlite-00020-00017  ['--disable-shared', '--disable-threadsafe', '...
# 378  isqlite-00020-00018  ['--disable-shared', '--disable-libtool-lock',...
# 379  isqlite-00020-00019  ['--disable-shared', '--disable-option-checkin...
#
#      bt_real  BinarySize
# 0     0.0110     9648880
# 1    30.2950     9648880
# 2     0.0110     9648880
# 3     0.0115     9648880
# 4    70.2090    10190888
# ..       ...         ...
# 375   0.0100    10084648
# 376  27.6225    10084648
# 377  29.1355    10084648
# 378  24.9405    10084648
# 379   0.0090    10084648
#
# [380 rows x 4 columns]
