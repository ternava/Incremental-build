# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd

# Find the average of clean Built Time (column "bt_real")
# and the average of Binary Size in both executions 

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved their average to a new CSV file

df.to_csv(path + 'rez_sample_03ALL/buildtime_dc2.csv')
df
# Out:
#         Branch                                             Option  bt_real  \
# 0   x264-00001  ['--disable-interlaced', '--bit-depth=8', '--c...  38.0855
# 1   x264-00002  ['--disable-gpl', '--bit-depth=8', '--chroma-f...  38.5975
# 2   x264-00003  ['--disable-asm', '--disable-gpl', '--disable-...  34.9095
# 3   x264-00004  ['--disable-gpl', '--disable-interlaced', '--b...  70.5765
# 4   x264-00005  ['--disable-asm', '--disable-interlaced', '--b...  38.2440
# 5   x264-00006  ['--disable-interlaced', '--bit-depth=all', '-...  65.9980
# 6   x264-00007  ['--disable-asm', '--disable-gpl', '--bit-dept...  21.2960
# 7   x264-00008  ['--disable-asm', '--disable-thread', '--disab...  20.7945
# 8   x264-00009  ['--bit-depth=all', '--chroma-format=400', '--...  66.4020
# 9   x264-00010  ['--disable-gpl', '--disable-thread', '--disab...  32.2695
# 10  x264-00011  ['--disable-gpl', '--disable-thread', '--disab...  65.7215
# 11  x264-00012  ['--disable-interlaced', '--bit-depth=8', '--c...  38.1305
# 12  x264-00013  ['--disable-asm', '--disable-interlaced', '--b...  20.6075
# 13  x264-00014  ['--disable-asm', '--disable-thread', '--disab...  17.8970
# 14  x264-00015  ['--disable-asm', '--bit-depth=all', '--chroma...  33.9135
# 15  x264-00016  ['--disable-asm', '--disable-gpl', '--disable-...  18.5670
# 16  x264-00017  ['--disable-gpl', '--disable-win32thread', '--...  40.7360
# 17  x264-00018  ['--disable-asm', '--disable-gpl', '--disable-...  19.1355
# 18  x264-00019  ['--disable-asm', '--disable-gpl', '--disable-...  35.1500
# 19  x264-00020  ['--disable-interlaced', '--bit-depth=8', '--c...  37.8700
#
#     BinarySize
# 0      1913968
# 1      1938720
# 2      2278824
# 3      3047312
# 4      2442528
# 5      2845544
# 6      1601416
# 7      1657760
# 8      2836352
# 9      1749400
# 10     2838496
# 11     1914320
# 12     1572712
# 13     1463912
# 14     2223376
# 15     1554512
# 16     2046072
# 17     1564568
# 18     2281776
# 19     1914320

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd

# Find the average of incremental Built Time (column "bt_real")
# and the average of Binary Size in both executions 

df1 = pd.read_csv(path + 'rez_sample_03I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_03II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved their average to a new CSV file

df.to_csv(path + 'rez_sample_03ALL/buildtime_di1.csv')
df
# Out:
#                 Branch                                             Option  \
# 0    ix264-00001-00002  ['--disable-gpl', '--bit-depth=8', '--chroma-f...
# 1    ix264-00001-00003  ['--disable-asm', '--disable-gpl', '--disable-...
# 2    ix264-00001-00004  ['--disable-gpl', '--disable-interlaced', '--b...
# 3    ix264-00001-00005  ['--disable-asm', '--disable-interlaced', '--b...
# 4    ix264-00001-00006  ['--disable-interlaced', '--bit-depth=all', '-...
# ..                 ...                                                ...
# 375  ix264-00020-00015  ['--disable-asm', '--bit-depth=all', '--chroma...
# 376  ix264-00020-00016  ['--disable-asm', '--disable-gpl', '--disable-...
# 377  ix264-00020-00017  ['--disable-gpl', '--disable-win32thread', '--...
# 378  ix264-00020-00018  ['--disable-asm', '--disable-gpl', '--disable-...
# 379  ix264-00020-00019  ['--disable-asm', '--disable-gpl', '--disable-...
#
#      bt_real  BinarySize
# 0    38.6940     1938720
# 1    34.4570     2278824
# 2    70.3545     3047312
# 3    38.1065     2442528
# 4    66.4115     2845544
# ..       ...         ...
# 375  33.4645     2223376
# 376  18.2225     1554512
# 377  40.0620     2046072
# 378  18.8360     1564568
# 379  34.5800     2281776
#
# [380 rows x 4 columns]
