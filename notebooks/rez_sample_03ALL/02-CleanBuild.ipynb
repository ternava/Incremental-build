# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# It shows the clean Build Time and the executable's Binary Size 
# for all built system's configurations

path = '/src/data/rez_sample_03ALL/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#     Unnamed: 0       Branch  \
# 0            0  xterm-00001
# 1            1  xterm-00002
# 2            2  xterm-00003
# 3            3  xterm-00004
# 4            4  xterm-00005
# 5            5  xterm-00006
# 6            6  xterm-00007
# 7            7  xterm-00008
# 8            8  xterm-00009
# 9            9  xterm-00010
# 10          10  xterm-00011
# 11          11  xterm-00012
# 12          12  xterm-00013
# 13          13  xterm-00014
# 14          14  xterm-00015
# 15          15  xterm-00016
# 16          16  xterm-00017
# 17          17  xterm-00018
# 18          18  xterm-00019
# 19          19  xterm-00020
#
#                                                Option  Build Time  Binary Size
# 0   ['--disable-ansi-color', '--disable-256-color'...      8.6040      2736120
# 1   ['--disable-ansi-color', '--disable-direct-col...      8.2440      2468160
# 2   ['--disable-ansi-color', '--disable-direct-col...     11.6390      3202648
# 3   ['--disable-ansi-color', '--disable-direct-col...     11.3290      3344192
# 4   ['--disable-16-color', '--disable-256-color', ...     11.8175      3456200
# 5   ['--disable-ansi-color', '--disable-16-color',...     10.2265      3015768
# 6   ['--disable-ansi-color', '--disable-16-color',...      9.7415      2857160
# 7   ['--disable-active-icon', '--disable-ansi-colo...      9.9600      2902288
# 8   ['--disable-ansi-color', '--disable-bold-color...     11.5310      3218472
# 9   ['--disable-active-icon', '--disable-16-color'...     10.7720      3023648
# 10  ['--disable-active-icon', '--disable-16-color'...      9.8925      2904408
# 11  ['--disable-active-icon', '--disable-ansi-colo...      9.0840      2883584
# 12  ['--disable-active-icon', '--disable-16-color'...     10.1660      3015848
# 13  ['--disable-ansi-color', '--disable-256-color'...      8.9135      2743048
# 14  ['--disable-active-icon', '--disable-16-color'...     10.2610      3057856
# 15  ['--disable-ansi-color', '--disable-direct-col...      9.8295      2862200
# 16  ['--disable-16-color', '--disable-256-color', ...      7.6720      2393760
# 17  ['--disable-active-icon', '--disable-16-color'...      8.6340      2739752
# 18  ['--disable-ansi-color', '--disable-blink-curs...     11.8460      3295512
# 19  ['--disable-ansi-color', '--disable-16-color',...     10.9115      3034008

# %%
# From the previous row data, here are extracted only 
# the clean Build Time and Binary Size data 

# The "BranchC" column show the name of built configurations.
# e.g., 00005 is the /configuration/sample-quicktest/00003.config 

df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
# Saved these data to a new CSV file

dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001        8.6040      2736120
# 00002        8.2440      2468160
# 00003       11.6390      3202648
# 00004       11.3290      3344192
# 00005       11.8175      3456200
# 00006       10.2265      3015768
# 00007        9.7415      2857160
# 00008        9.9600      2902288
# 00009       11.5310      3218472
# 00010       10.7720      3023648
# 00011        9.8925      2904408
# 00012        9.0840      2883584
# 00013       10.1660      3015848
# 00014        8.9135      2743048
# 00015       10.2610      3057856
# 00016        9.8295      2862200
# 00017        7.6720      2393760
# 00018        8.6340      2739752
# 00019       11.8460      3295512
# 00020       10.9115      3034008
