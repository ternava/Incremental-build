# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# It shows the clean Build Time and the executable's Binary Size 
# for all built system's configurations

path = '/src/data/rez_sample_04ALL/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#     Unnamed: 0      Branch                                             Option  \
# 0            0  curl-00001  ['--disable-shared', '--disable-largefile', '-...
# 1            1  curl-00002  ['--disable-shared', '--enable-debug', '--enab...
# 2            2  curl-00003  ['--disable-shared', '--disable-largefile', '-...
# 3            3  curl-00004  ['--disable-shared', '--disable-largefile', '-...
# 4            4  curl-00005  ['--disable-shared', '--enable-silent-rules', ...
# 5            5  curl-00006  ['--disable-shared', '--disable-largefile', '-...
# 6            6  curl-00007  ['--disable-shared', '--disable-silent-rules',...
# 7            7  curl-00008  ['--disable-shared', '--disable-libtool-lock',...
# 8            8  curl-00009  ['--disable-shared', '--disable-largefile', '-...
# 9            9  curl-00010  ['--disable-shared', '--disable-libtool-lock',...
# 10          10  curl-00011  ['--disable-shared', '--disable-largefile', '-...
# 11          11  curl-00012  ['--disable-shared', '--disable-largefile', '-...
# 12          12  curl-00013  ['--disable-shared', '--disable-libtool-lock',...
# 13          13  curl-00014  ['--disable-shared', '--disable-libtool-lock',...
# 14          14  curl-00015  ['--disable-shared', '--disable-largefile', '-...
# 15          15  curl-00016  ['--disable-shared', '--disable-largefile', '-...
# 16          16  curl-00017  ['--disable-shared', '--disable-largefile', '-...
# 17          17  curl-00018  ['--disable-shared', '--disable-largefile', '-...
# 18          18  curl-00019  ['--disable-shared', '--disable-largefile', '-...
# 19          19  curl-00020  ['--disable-shared', '--disable-largefile', '-...
#
#     Build Time  Binary Size
# 0      28.6115      4687080
# 1      71.5060      4635488
# 2      33.5315      4636680
# 3      39.8600      2990584
# 4      25.2630      1373432
# 5      67.2090      4527608
# 6      30.8705      3779760
# 7      28.3050      4899584
# 8      29.6075      3838136
# 9      50.1270      2970256
# 10     23.4730       569576
# 11     41.1550      3373904
# 12     23.4010       611888
# 13     23.5800      4429120
# 14     44.9750      4115888
# 15     23.3495       734264
# 16     25.3025       855168
# 17     22.9720      3779784
# 18     44.9745      4119800
# 19     29.2680      4077992

# %%
# From the previous row data, here are extracted only 
# the clean Build Time and Binary Size data 

# The "BranchC" column show the name of built configurations.
# e.g., 00005 is the /configuration/sample-quicktest/00003.config 

df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
# Saved these data to a new CSV file

dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001       28.6115      4687080
# 00002       71.5060      4635488
# 00003       33.5315      4636680
# 00004       39.8600      2990584
# 00005       25.2630      1373432
# 00006       67.2090      4527608
# 00007       30.8705      3779760
# 00008       28.3050      4899584
# 00009       29.6075      3838136
# 00010       50.1270      2970256
# 00011       23.4730       569576
# 00012       41.1550      3373904
# 00013       23.4010       611888
# 00014       23.5800      4429120
# 00015       44.9750      4115888
# 00016       23.3495       734264
# 00017       25.3025       855168
# 00018       22.9720      3779784
# 00019       44.9745      4119800
# 00020       29.2680      4077992
