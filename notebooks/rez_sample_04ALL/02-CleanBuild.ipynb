# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# It shows the clean Build Time and the executable's Binary Size 
# for all built system's configurations

path = '/src/data/rez_sample_04ALL/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#     Unnamed: 0        Branch  \
# 0            0  sqlite-00001
# 1            1  sqlite-00002
# 2            2  sqlite-00003
# 3            3  sqlite-00004
# 4            4  sqlite-00005
# 5            5  sqlite-00006
# 6            6  sqlite-00007
# 7            7  sqlite-00008
# 8            8  sqlite-00009
# 9            9  sqlite-00010
# 10          10  sqlite-00011
# 11          11  sqlite-00012
# 12          12  sqlite-00013
# 13          13  sqlite-00014
# 14          14  sqlite-00015
# 15          15  sqlite-00016
# 16          16  sqlite-00017
# 17          17  sqlite-00018
# 18          18  sqlite-00019
# 19          19  sqlite-00020
#
#                                                Option  Build Time  Binary Size
# 0   ['--disable-readline', '--disable-load-extensi...    103.2485     10169536
# 1   ['--disable-option-checking', '--disable-libto...     94.2445      9971000
# 2   ['--disable-threadsafe', '--disable-load-exten...    101.8945     10091928
# 3   ['--disable-option-checking', '--disable-libto...    103.7970     10202064
# 4   ['--disable-libtool-lock', '--disable-threadsa...     83.6320      8813696
# 5   ['--disable-option-checking', '--disable-libto...     98.7115     10218592
# 6   ['--disable-readline', '--enable-fast-install'...     90.2395      9681744
# 7   ['--disable-option-checking', '--disable-threa...    101.6725     10068864
# 8   ['--disable-largefile', '--disable-threadsafe'...     82.2850      8465896
# 9   ['--disable-option-checking', '--disable-libto...     91.8325      9056568
# 10  ['--disable-largefile', '--disable-threadsafe'...     82.9525      8992656
# 11  ['--disable-libtool-lock', '--disable-largefil...     87.0480      8794376
# 12  ['--disable-largefile', '--disable-amalgamatio...     89.9095     10147616
# 13  ['--disable-option-checking', '--disable-libto...    105.1705     10203856
# 14  ['--disable-option-checking', '--disable-libto...     87.0505      9033160
# 15  ['--disable-option-checking', '--disable-tcl',...     96.4040     10155008
# 16  ['--disable-libtool-lock', '--disable-tcl', '-...     84.8040      9042240
# 17  ['--disable-option-checking', '--disable-libto...    103.3230     10173488
# 18  ['--disable-readline', '--disable-math', '--en...    103.5850     10189256
# 19  ['--disable-option-checking', '--disable-readl...     96.5780     10169536

# %%
# From the previous row data, here are extracted only 
# the clean Build Time and Binary Size data 

# The "BranchC" column show the name of built configurations.
# e.g., 00005 is the /configuration/sample-quicktest/00003.config 

df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
# Saved these data to a new CSV file

dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001      103.2485     10169536
# 00002       94.2445      9971000
# 00003      101.8945     10091928
# 00004      103.7970     10202064
# 00005       83.6320      8813696
# 00006       98.7115     10218592
# 00007       90.2395      9681744
# 00008      101.6725     10068864
# 00009       82.2850      8465896
# 00010       91.8325      9056568
# 00011       82.9525      8992656
# 00012       87.0480      8794376
# 00013       89.9095     10147616
# 00014      105.1705     10203856
# 00015       87.0505      9033160
# 00016       96.4040     10155008
# 00017       84.8040      9042240
# 00018      103.3230     10173488
# 00019      103.5850     10189256
# 00020       96.5780     10169536
