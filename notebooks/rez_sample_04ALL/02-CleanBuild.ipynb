# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# It shows the clean Build Time and the executable's Binary Size 
# for all built system's configurations

path = '/src/data/rez_sample_04ALL/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#     Unnamed: 0      Branch                                             Option  \
# 0            0  x264-00001  ['--disable-interlaced', '--bit-depth=8', '--c...
# 1            1  x264-00002  ['--disable-gpl', '--bit-depth=8', '--chroma-f...
# 2            2  x264-00003  ['--disable-asm', '--disable-gpl', '--disable-...
# 3            3  x264-00004  ['--disable-gpl', '--disable-interlaced', '--b...
# 4            4  x264-00005  ['--disable-asm', '--disable-interlaced', '--b...
# 5            5  x264-00006  ['--disable-interlaced', '--bit-depth=all', '-...
# 6            6  x264-00007  ['--disable-asm', '--disable-gpl', '--bit-dept...
# 7            7  x264-00008  ['--disable-asm', '--disable-thread', '--disab...
# 8            8  x264-00009  ['--bit-depth=all', '--chroma-format=400', '--...
# 9            9  x264-00010  ['--disable-gpl', '--disable-thread', '--disab...
# 10          10  x264-00011  ['--disable-gpl', '--disable-thread', '--disab...
# 11          11  x264-00012  ['--disable-interlaced', '--bit-depth=8', '--c...
# 12          12  x264-00013  ['--disable-asm', '--disable-interlaced', '--b...
# 13          13  x264-00014  ['--disable-asm', '--disable-thread', '--disab...
# 14          14  x264-00015  ['--disable-asm', '--bit-depth=all', '--chroma...
# 15          15  x264-00016  ['--disable-asm', '--disable-gpl', '--disable-...
# 16          16  x264-00017  ['--disable-gpl', '--disable-win32thread', '--...
# 17          17  x264-00018  ['--disable-asm', '--disable-gpl', '--disable-...
# 18          18  x264-00019  ['--disable-asm', '--disable-gpl', '--disable-...
# 19          19  x264-00020  ['--disable-interlaced', '--bit-depth=8', '--c...
#
#     Build Time  Binary Size
# 0      38.0855      1913968
# 1      38.5975      1938720
# 2      34.9095      2278824
# 3      70.5765      3047312
# 4      38.2440      2442528
# 5      65.9980      2845544
# 6      21.2960      1601416
# 7      20.7945      1657760
# 8      66.4020      2836352
# 9      32.2695      1749400
# 10     65.7215      2838496
# 11     38.1305      1914320
# 12     20.6075      1572712
# 13     17.8970      1463912
# 14     33.9135      2223376
# 15     18.5670      1554512
# 16     40.7360      2046072
# 17     19.1355      1564568
# 18     35.1500      2281776
# 19     37.8700      1914320

# %%
# From the previous row data, here are extracted only 
# the clean Build Time and Binary Size data 

# The "BranchC" column show the name of built configurations.
# e.g., 00005 is the /configuration/sample-quicktest/00003.config 

df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
# Saved these data to a new CSV file

dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001       38.0855      1913968
# 00002       38.5975      1938720
# 00003       34.9095      2278824
# 00004       70.5765      3047312
# 00005       38.2440      2442528
# 00006       65.9980      2845544
# 00007       21.2960      1601416
# 00008       20.7945      1657760
# 00009       66.4020      2836352
# 00010       32.2695      1749400
# 00011       65.7215      2838496
# 00012       38.1305      1914320
# 00013       20.6075      1572712
# 00014       17.8970      1463912
# 00015       33.9135      2223376
# 00016       18.5670      1554512
# 00017       40.7360      2046072
# 00018       19.1355      1564568
# 00019       35.1500      2281776
# 00020       37.8700      1914320
