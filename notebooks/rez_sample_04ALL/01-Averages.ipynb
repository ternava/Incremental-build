# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd

# Find the average of clean Built Time (column "bt_real")
# and the average of Binary Size in both executions 

path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved their average to a new CSV file

df.to_csv(path + 'rez_sample_04ALL/buildtime_dc2.csv')
df
# Out:
#         Branch                                             Option  bt_real  \
# 0   x264-00001  ['--bit-depth=8', '--chroma-format=422', '--di...  38.0870
# 1   x264-00002  ['--disable-asm', '--disable-thread', '--disab...  18.4890
# 2   x264-00003  ['--disable-asm', '--disable-thread', '--disab...  18.3085
# 3   x264-00004  ['--disable-thread', '--disable-win32thread', ...  31.3090
# 4   x264-00005  ['--disable-gpl', '--disable-thread', '--bit-d...  69.8580
# 5   x264-00006  ['--disable-gpl', '--disable-thread', '--bit-d...  65.4565
# 6   x264-00007  ['--disable-asm', '--disable-gpl', '--disable-...  17.7295
# 7   x264-00008  ['--disable-gpl', '--disable-win32thread', '--...  34.4460
# 8   x264-00009  ['--bit-depth=8', '--chroma-format=all', '--en...  40.1165
# 9   x264-00010  ['--disable-asm', '--disable-thread', '--bit-d...  34.1815
# 10  x264-00011  ['--disable-asm', '--disable-gpl', '--bit-dept...  34.5595
# 11  x264-00012  ['--disable-thread', '--disable-win32thread', ...  64.4365
# 12  x264-00013  ['--disable-gpl', '--disable-thread', '--disab...  36.3965
# 13  x264-00014  ['--disable-asm', '--disable-gpl', '--disable-...  18.2535
# 14  x264-00015  ['--disable-asm', '--disable-thread', '--bit-d...  33.6175
# 15  x264-00016  ['--bit-depth=all', '--chroma-format=all', '--...  70.7305
# 16  x264-00017  ['--disable-asm', '--disable-gpl', '--disable-...  34.0290
# 17  x264-00018  ['--disable-asm', '--disable-interlaced', '--b...  18.4350
# 18  x264-00019  ['--disable-win32thread', '--bit-depth=8', '--...  38.1790
# 19  x264-00020  ['--disable-thread', '--bit-depth=10', '--chro...  31.3535
#
#     BinarySize
# 0      1938928
# 1      1488112
# 2      1554512
# 3      1720304
# 4      3094224
# 5      2879792
# 6      1440352
# 7      1866608
# 8      2046072
# 9      2278824
# 10     2281400
# 11     2825856
# 12     1879304
# 13     1554512
# 14     2271288
# 15     3108808
# 16     2278824
# 17     1539400
# 18     1942672
# 19     1720304

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd

# Find the average of incremental Built Time (column "bt_real")
# and the average of Binary Size in both executions 

df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved their average to a new CSV file

df.to_csv(path + 'rez_sample_04ALL/buildtime_di1.csv')
df
# Out:
#                 Branch                                             Option  \
# 0    ix264-00001-00002  ['--disable-asm', '--disable-thread', '--disab...
# 1    ix264-00001-00003  ['--disable-asm', '--disable-thread', '--disab...
# 2    ix264-00001-00004  ['--disable-thread', '--disable-win32thread', ...
# 3    ix264-00001-00005  ['--disable-gpl', '--disable-thread', '--bit-d...
# 4    ix264-00001-00006  ['--disable-gpl', '--disable-thread', '--bit-d...
# ..                 ...                                                ...
# 375  ix264-00020-00015  ['--disable-asm', '--disable-thread', '--bit-d...
# 376  ix264-00020-00016  ['--bit-depth=all', '--chroma-format=all', '--...
# 377  ix264-00020-00017  ['--disable-asm', '--disable-gpl', '--disable-...
# 378  ix264-00020-00018  ['--disable-asm', '--disable-interlaced', '--b...
# 379  ix264-00020-00019  ['--disable-win32thread', '--bit-depth=8', '--...
#
#      bt_real  BinarySize
# 0    18.7095     1488112
# 1    18.5435     1554512
# 2    31.3475     1720304
# 3    70.0970     3094224
# 4    65.6250     2879792
# ..       ...         ...
# 375  33.9120     2271288
# 376  71.9760     3108808
# 377  34.6995     2278824
# 378  18.5610     1539400
# 379  38.8775     1942672
#
# [380 rows x 4 columns]
