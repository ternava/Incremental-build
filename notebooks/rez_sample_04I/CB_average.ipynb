# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_04ALL/buildtime_dc2.csv')

df
# Out:
#       Branch                                             Option  bt_real  \
# 0   xz-00001  ['--enable-debug', '--enable-encoders=lzma1,de...  10.3815
# 1   xz-00002  ['--enable-encoders=lzma1,armthumb', '--enable...  10.0755
# 2   xz-00003  ['--enable-debug', '--enable-encoders=lzma1,ia...  11.0055
# 3   xz-00004  ['--enable-encoders=lzma1,x86', '--enable-deco...   9.7470
# 4   xz-00005  ['--enable-encoders=lzma1,lzma2', '--enable-de...  10.0235
# 5   xz-00006  ['--enable-debug', '--enable-encoders=lzma1', ...  10.2005
# 6   xz-00007  ['--enable-debug', '--enable-encoders=lzma1,lz...   9.9430
# 7   xz-00008  ['--enable-encoders=lzma1', '--enable-decoders...   9.6935
# 8   xz-00009  ['--enable-debug', '--enable-encoders=lzma1,x8...  10.0025
# 9   xz-00010  ['--enable-debug', '--enable-encoders=lzma1,x8...  10.8960
# 10  xz-00011  ['--enable-encoders=lzma1', '--enable-decoders...   9.9595
# 11  xz-00012  ['--enable-encoders=lzma1,arm', '--enable-deco...   9.8560
# 12  xz-00013  ['--enable-encoders=lzma1,delta', '--enable-de...  10.7375
# 13  xz-00014  ['--enable-debug', '--enable-encoders=lzma1,lz...  11.4680
# 14  xz-00015  ['--enable-debug', '--enable-encoders=lzma1,x8...   9.9780
# 15  xz-00016  ['--enable-debug', '--enable-encoders=lzma1,lz...  10.1830
# 16  xz-00017  ['--enable-debug', '--enable-encoders=lzma1,lz...  11.6315
# 17  xz-00018  ['--enable-debug', '--enable-encoders=lzma1,lz...  11.0820
# 18  xz-00019  ['--enable-encoders=lzma1,powerpc', '--enable-...   9.8160
# 19  xz-00020  ['--enable-encoders=lzma1', '--enable-decoders...   9.8275
#
#     BinarySize
# 0      1230232
# 1      1062464
# 2      1240560
# 3       988312
# 4      1069992
# 5      1239264
# 6      1102320
# 7       960144
# 8      1110768
# 9      1252072
# 10     1144584
# 11     1069496
# 12     1127720
# 13     1222720
# 14     1155304
# 15     1075712
# 16     1219080
# 17     1115768
# 18      995744
# 19     1057024

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_04ALL/buildtime_di1.csv')

df
# Out:
#               Branch                                             Option  \
# 0    ixz-00001-00002  ['--enable-encoders=lzma1,armthumb', '--enable...
# 1    ixz-00001-00003  ['--enable-debug', '--enable-encoders=lzma1,ia...
# 2    ixz-00001-00004  ['--enable-encoders=lzma1,x86', '--enable-deco...
# 3    ixz-00001-00005  ['--enable-encoders=lzma1,lzma2', '--enable-de...
# 4    ixz-00001-00006  ['--enable-debug', '--enable-encoders=lzma1', ...
# ..               ...                                                ...
# 375  ixz-00020-00015  ['--enable-debug', '--enable-encoders=lzma1,x8...
# 376  ixz-00020-00016  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 377  ixz-00020-00017  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 378  ixz-00020-00018  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 379  ixz-00020-00019  ['--enable-encoders=lzma1,powerpc', '--enable-...
#
#      bt_real  BinarySize
# 0    -1.0000          -1
# 1    -1.0000          -1
# 2    -1.0000          -1
# 3    -1.0000          -1
# 4    -1.0000          -1
# ..       ...         ...
# 375  -1.0000          -1
# 376  10.3055     1075712
# 377  11.5275     1219080
# 378  11.0140     1115768
# 379  -1.0000          -1
#
# [380 rows x 4 columns]
