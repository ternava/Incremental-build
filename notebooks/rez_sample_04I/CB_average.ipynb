# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_04ALL/buildtime_dc2.csv')

df
# Out:
#          Branch                                             Option  bt_real  \
# 0   xterm-00001  ['--disable-ansi-color', '--disable-88-color',...  11.4075
# 1   xterm-00002  ['--disable-ansi-color', '--disable-16-color',...  11.3205
# 2   xterm-00003  ['--disable-active-icon', '--disable-direct-co...  10.4600
# 3   xterm-00004  ['--disable-16-color', '--disable-256-color', ...   8.8805
# 4   xterm-00005  ['--disable-ansi-color', '--disable-16-color',...  10.1895
# 5   xterm-00006  ['--disable-active-icon', '--disable-16-color'...  10.2005
# 6   xterm-00007  ['--disable-active-icon', '--disable-ansi-colo...   9.0820
# 7   xterm-00008  ['--disable-ansi-color', '--disable-256-color'...   8.3325
# 8   xterm-00009  ['--disable-active-icon', '--disable-256-color...  12.7955
# 9   xterm-00010  ['--disable-16-color', '--disable-direct-color...  10.7645
# 10  xterm-00011  ['--disable-active-icon', '--disable-ansi-colo...  10.4645
# 11  xterm-00012  ['--disable-active-icon', '--disable-ansi-colo...  10.8065
# 12  xterm-00013  ['--disable-active-icon', '--disable-ansi-colo...   8.5250
# 13  xterm-00014  ['--disable-direct-color', '--disable-blink-cu...  11.7425
# 14  xterm-00015  ['--disable-ansi-color', '--disable-88-color',...  11.6770
# 15  xterm-00016  ['--disable-ansi-color', '--disable-88-color',...   9.8830
# 16  xterm-00017  ['--disable-16-color', '--disable-256-color', ...   7.6045
# 17  xterm-00018  ['--disable-16-color', '--disable-direct-color...  11.7635
# 18  xterm-00019  ['--disable-ansi-color', '--disable-16-color',...  10.5900
# 19  xterm-00020  ['--disable-ansi-color', '--disable-16-color',...   8.4485
#
#     BinarySize
# 0      3255944
# 1      3239240
# 2      3020352
# 3      2676232
# 4      2951672
# 5      2978064
# 6      2644256
# 7      2620824
# 8      3539272
# 9      3051592
# 10     2934360
# 11     3189624
# 12     2562776
# 13     3362936
# 14     3284152
# 15     2735152
# 16     2407800
# 17     3385544
# 18     2878640
# 19     2633736

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_04ALL/buildtime_di1.csv')

df
# Out:
#                  Branch                                             Option  \
# 0    ixterm-00001-00002  ['--disable-ansi-color', '--disable-16-color',...
# 1    ixterm-00001-00003  ['--disable-active-icon', '--disable-direct-co...
# 2    ixterm-00001-00004  ['--disable-16-color', '--disable-256-color', ...
# 3    ixterm-00001-00005  ['--disable-ansi-color', '--disable-16-color',...
# 4    ixterm-00001-00006  ['--disable-active-icon', '--disable-16-color'...
# ..                  ...                                                ...
# 375  ixterm-00020-00015  ['--disable-ansi-color', '--disable-88-color',...
# 376  ixterm-00020-00016  ['--disable-ansi-color', '--disable-88-color',...
# 377  ixterm-00020-00017  ['--disable-16-color', '--disable-256-color', ...
# 378  ixterm-00020-00018  ['--disable-16-color', '--disable-direct-color...
# 379  ixterm-00020-00019  ['--disable-ansi-color', '--disable-16-color',...
#
#      bt_real  BinarySize
# 0    11.1115     3239240
# 1    10.2715     3020352
# 2     8.7345     2676232
# 3    10.1130     2951672
# 4    10.3190     2978064
# ..       ...         ...
# 375  11.3125     3284152
# 376   9.7600     2735152
# 377   7.5115     2407800
# 378  11.7455     3385544
# 379  10.5820     2878640
#
# [380 rows x 4 columns]
