# %% [markdown]
# Average of clean build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_dc2.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_dc2.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_04ALL/buildtime_dc2.csv')

df
# Out:
#         Branch                                             Option  bt_real  \
# 0   curl-00001  ['--disable-shared', '--disable-largefile', '-...  28.6115
# 1   curl-00002  ['--disable-shared', '--enable-debug', '--enab...  71.5060
# 2   curl-00003  ['--disable-shared', '--disable-largefile', '-...  33.5315
# 3   curl-00004  ['--disable-shared', '--disable-largefile', '-...  39.8600
# 4   curl-00005  ['--disable-shared', '--enable-silent-rules', ...  25.2630
# 5   curl-00006  ['--disable-shared', '--disable-largefile', '-...  67.2090
# 6   curl-00007  ['--disable-shared', '--disable-silent-rules',...  30.8705
# 7   curl-00008  ['--disable-shared', '--disable-libtool-lock',...  28.3050
# 8   curl-00009  ['--disable-shared', '--disable-largefile', '-...  29.6075
# 9   curl-00010  ['--disable-shared', '--disable-libtool-lock',...  50.1270
# 10  curl-00011  ['--disable-shared', '--disable-largefile', '-...  23.4730
# 11  curl-00012  ['--disable-shared', '--disable-largefile', '-...  41.1550
# 12  curl-00013  ['--disable-shared', '--disable-libtool-lock',...  23.4010
# 13  curl-00014  ['--disable-shared', '--disable-libtool-lock',...  23.5800
# 14  curl-00015  ['--disable-shared', '--disable-largefile', '-...  44.9750
# 15  curl-00016  ['--disable-shared', '--disable-largefile', '-...  23.3495
# 16  curl-00017  ['--disable-shared', '--disable-largefile', '-...  25.3025
# 17  curl-00018  ['--disable-shared', '--disable-largefile', '-...  22.9720
# 18  curl-00019  ['--disable-shared', '--disable-largefile', '-...  44.9745
# 19  curl-00020  ['--disable-shared', '--disable-largefile', '-...  29.2680
#
#     BinarySize
# 0      4687080
# 1      4635488
# 2      4636680
# 3      2990584
# 4      1373432
# 5      4527608
# 6      3779760
# 7      4899584
# 8      3838136
# 9      2970256
# 10      569576
# 11     3373904
# 12      611888
# 13     4429120
# 14     4115888
# 15      734264
# 16      855168
# 17     3779784
# 18     4119800
# 19     4077992

# %% [markdown]
# Average of incremental build for sample_03

# %%
import numpy as np
import pandas as pd


path = '/home/xternava/Documents/GitHub/Incremental-build/data/'
#path = '/src/data/'
df1 = pd.read_csv(path + 'rez_sample_04I/buildtime_di1.csv')
df2 = pd.read_csv(path + 'rez_sample_04II/buildtime_di1.csv')

df = pd.concat([df1, df2])
df = df.groupby(['Branch', 'Option']).agg({
    "bt_real":np.mean,
    "BinarySize": np.mean
}).reset_index()

# Saved to a new csv file
#df = df.sort_index()
df.to_csv(path + 'rez_sample_04ALL/buildtime_di1.csv')

df
# Out:
#                 Branch                                             Option  \
# 0    icurl-00001-00002  ['--disable-shared', '--enable-debug', '--enab...
# 1    icurl-00001-00003  ['--disable-shared', '--disable-largefile', '-...
# 2    icurl-00001-00004  ['--disable-shared', '--disable-largefile', '-...
# 3    icurl-00001-00005  ['--disable-shared', '--enable-silent-rules', ...
# 4    icurl-00001-00006  ['--disable-shared', '--disable-largefile', '-...
# ..                 ...                                                ...
# 375  icurl-00020-00015  ['--disable-shared', '--disable-largefile', '-...
# 376  icurl-00020-00016  ['--disable-shared', '--disable-largefile', '-...
# 377  icurl-00020-00017  ['--disable-shared', '--disable-largefile', '-...
# 378  icurl-00020-00018  ['--disable-shared', '--disable-largefile', '-...
# 379  icurl-00020-00019  ['--disable-shared', '--disable-largefile', '-...
#
#      bt_real  BinarySize
# 0    68.0125     4635488
# 1    29.6170     4636688
# 2    36.7485     2990584
# 3    21.3245     1373432
# 4    65.7340     4527616
# ..       ...         ...
# 375  42.6040     4115888
# 376  19.7700      734264
# 377  21.7705      855168
# 378  19.3740     3779784
# 379  42.0625     4119800
#
# [380 rows x 4 columns]
