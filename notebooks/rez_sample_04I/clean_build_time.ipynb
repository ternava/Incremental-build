# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_04ALL/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#     Unnamed: 0    Branch                                             Option  \
# 0            0  xz-00001  ['--enable-debug', '--enable-encoders=lzma1,de...
# 1            1  xz-00002  ['--enable-encoders=lzma1,armthumb', '--enable...
# 2            2  xz-00003  ['--enable-debug', '--enable-encoders=lzma1,ia...
# 3            3  xz-00004  ['--enable-encoders=lzma1,x86', '--enable-deco...
# 4            4  xz-00005  ['--enable-encoders=lzma1,lzma2', '--enable-de...
# 5            5  xz-00006  ['--enable-debug', '--enable-encoders=lzma1', ...
# 6            6  xz-00007  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 7            7  xz-00008  ['--enable-encoders=lzma1', '--enable-decoders...
# 8            8  xz-00009  ['--enable-debug', '--enable-encoders=lzma1,x8...
# 9            9  xz-00010  ['--enable-debug', '--enable-encoders=lzma1,x8...
# 10          10  xz-00011  ['--enable-encoders=lzma1', '--enable-decoders...
# 11          11  xz-00012  ['--enable-encoders=lzma1,arm', '--enable-deco...
# 12          12  xz-00013  ['--enable-encoders=lzma1,delta', '--enable-de...
# 13          13  xz-00014  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 14          14  xz-00015  ['--enable-debug', '--enable-encoders=lzma1,x8...
# 15          15  xz-00016  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 16          16  xz-00017  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 17          17  xz-00018  ['--enable-debug', '--enable-encoders=lzma1,lz...
# 18          18  xz-00019  ['--enable-encoders=lzma1,powerpc', '--enable-...
# 19          19  xz-00020  ['--enable-encoders=lzma1', '--enable-decoders...
#
#     Build Time  Binary Size
# 0      10.3815      1230232
# 1      10.0755      1062464
# 2      11.0055      1240560
# 3       9.7470       988312
# 4      10.0235      1069992
# 5      10.2005      1239264
# 6       9.9430      1102320
# 7       9.6935       960144
# 8      10.0025      1110768
# 9      10.8960      1252072
# 10      9.9595      1144584
# 11      9.8560      1069496
# 12     10.7375      1127720
# 13     11.4680      1222720
# 14      9.9780      1155304
# 15     10.1830      1075712
# 16     11.6315      1219080
# 17     11.0820      1115768
# 18      9.8160       995744
# 19      9.8275      1057024

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001       10.3815      1230232
# 00002       10.0755      1062464
# 00003       11.0055      1240560
# 00004        9.7470       988312
# 00005       10.0235      1069992
# 00006       10.2005      1239264
# 00007        9.9430      1102320
# 00008        9.6935       960144
# 00009       10.0025      1110768
# 00010       10.8960      1252072
# 00011        9.9595      1144584
# 00012        9.8560      1069496
# 00013       10.7375      1127720
# 00014       11.4680      1222720
# 00015        9.9780      1155304
# 00016       10.1830      1075712
# 00017       11.6315      1219080
# 00018       11.0820      1115768
# 00019        9.8160       995744
# 00020        9.8275      1057024
