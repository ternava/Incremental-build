# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_04ALL/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#           Branch                                             Option  \
# 0   sqlite-00001  ['--disable-readline', '--disable-load-extensi...
# 1   sqlite-00002  ['--disable-option-checking', '--disable-libto...
# 2   sqlite-00003  ['--disable-threadsafe', '--disable-load-exten...
# 3   sqlite-00004  ['--disable-option-checking', '--disable-libto...
# 4   sqlite-00005  ['--disable-libtool-lock', '--disable-threadsa...
# 5   sqlite-00006  ['--disable-option-checking', '--disable-libto...
# 6   sqlite-00007  ['--disable-readline', '--enable-fast-install'...
# 7   sqlite-00008  ['--disable-option-checking', '--disable-threa...
# 8   sqlite-00009  ['--disable-largefile', '--disable-threadsafe'...
# 9   sqlite-00010  ['--disable-option-checking', '--disable-libto...
# 10  sqlite-00011  ['--disable-largefile', '--disable-threadsafe'...
# 11  sqlite-00012  ['--disable-libtool-lock', '--disable-largefil...
# 12  sqlite-00013  ['--disable-largefile', '--disable-amalgamatio...
# 13  sqlite-00014  ['--disable-option-checking', '--disable-libto...
# 14  sqlite-00015  ['--disable-option-checking', '--disable-libto...
# 15  sqlite-00016  ['--disable-option-checking', '--disable-tcl',...
# 16  sqlite-00017  ['--disable-libtool-lock', '--disable-tcl', '-...
# 17  sqlite-00018  ['--disable-option-checking', '--disable-libto...
# 18  sqlite-00019  ['--disable-readline', '--disable-math', '--en...
# 19  sqlite-00020  ['--disable-option-checking', '--disable-readl...
#
#     Build Time  Binary Size
# 0     103.2485     10169536
# 1      94.2445      9971000
# 2     101.8945     10091928
# 3     103.7970     10202064
# 4      83.6320      8813696
# 5      98.7115     10218592
# 6      90.2395      9681744
# 7     101.6725     10068864
# 8      82.2850      8465896
# 9      91.8325      9056568
# 10     82.9525      8992656
# 11     87.0480      8794376
# 12     89.9095     10147616
# 13    105.1705     10203856
# 14     87.0505      9033160
# 15     96.4040     10155008
# 16     84.8040      9042240
# 17    103.3230     10173488
# 18    103.5850     10189256
# 19     96.5780     10169536

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001      103.2485     10169536
# 00002       94.2445      9971000
# 00003      101.8945     10091928
# 00004      103.7970     10202064
# 00005       83.6320      8813696
# 00006       98.7115     10218592
# 00007       90.2395      9681744
# 00008      101.6725     10068864
# 00009       82.2850      8465896
# 00010       91.8325      9056568
# 00011       82.9525      8992656
# 00012       87.0480      8794376
# 00013       89.9095     10147616
# 00014      105.1705     10203856
# 00015       87.0505      9033160
# 00016       96.4040     10155008
# 00017       84.8040      9042240
# 00018      103.3230     10173488
# 00019      103.5850     10189256
# 00020       96.5780     10169536
