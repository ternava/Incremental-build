# %% [markdown]
# # Make clean build time

# %%
import pandas as pd
import numpy as np

# %%
# Will show the clean build time and the executable's binary size for all system's configurations
path = '/home/xternava/Documents/GitHub/Incremental-build/data/rez_sample_04ALL/'
#path = '/src/data/'
df = pd.read_csv(path + 'buildtime_dc2.csv')
df.columns
df = df.rename(columns = {"bt_real": "Build Time", "BinarySize": "Binary Size"})
df
# Out:
#         Branch                                             Option  Build Time  \
# 0   x264-00006  ['--disable-gpl', '--disable-thread', '--bit-d...      65.636
# 1   x264-00015  ['--disable-asm', '--disable-thread', '--bit-d...      33.612
# 2   x264-00012  ['--disable-thread', '--disable-win32thread', ...      64.571
# 3   x264-00014  ['--disable-asm', '--disable-gpl', '--disable-...      18.262
# 4   x264-00005  ['--disable-gpl', '--disable-thread', '--bit-d...      69.989
# 5   x264-00020  ['--disable-thread', '--bit-depth=10', '--chro...      31.319
# 6   x264-00010  ['--disable-asm', '--disable-thread', '--bit-d...      34.387
# 7   x264-00004  ['--disable-thread', '--disable-win32thread', ...      31.363
# 8   x264-00007  ['--disable-asm', '--disable-gpl', '--disable-...      17.789
# 9   x264-00017  ['--disable-asm', '--disable-gpl', '--disable-...      33.982
# 10  x264-00008  ['--disable-gpl', '--disable-win32thread', '--...      34.490
# 11  x264-00009  ['--bit-depth=8', '--chroma-format=all', '--en...      40.111
# 12  x264-00019  ['--disable-win32thread', '--bit-depth=8', '--...      38.216
# 13  x264-00001  ['--bit-depth=8', '--chroma-format=422', '--di...      38.118
# 14  x264-00011  ['--disable-asm', '--disable-gpl', '--bit-dept...      34.639
# 15  x264-00016  ['--bit-depth=all', '--chroma-format=all', '--...      70.777
# 16  x264-00013  ['--disable-gpl', '--disable-thread', '--disab...      36.498
# 17  x264-00018  ['--disable-asm', '--disable-interlaced', '--b...      18.481
# 18  x264-00003  ['--disable-asm', '--disable-thread', '--disab...      18.326
# 19  x264-00002  ['--disable-asm', '--disable-thread', '--disab...      18.538
#
#     bt_user  bt_sys  Binary Size
# 0    63.436   2.029      2879792
# 1    31.865   1.670      2271288
# 2    62.437   2.013      2825856
# 3    17.070   1.156      1554512
# 4    67.677   2.157      3094224
# 5    30.082   1.166      1720304
# 6    32.578   1.728      2278824
# 7    30.029   1.251      1720304
# 8    16.597   1.134      1440352
# 9    32.128   1.775      2278824
# 10   32.993   1.415      1866608
# 11   38.597   1.441      2046072
# 12   36.694   1.455      1942672
# 13   36.580   1.469      1938928
# 14   32.601   1.959      2281400
# 15   68.312   2.320      3108808
# 16   35.136   1.297      1879304
# 17   17.198   1.249      1539400
# 18   17.146   1.152      1554512
# 19   17.460   1.028      1488112

# %%
df[['Br0', 'BranchC']] = df.Branch.str.split("-",expand=True)

df_setindex = df.set_index("BranchC")
df = df_setindex[['Build Time', 'Binary Size']]

# The index is reset to the clean build configuration
dx = df.sort_index()
dx.to_csv(path + 'clean-bt.csv')
dx
# Out:
#          Build Time  Binary Size
# BranchC
# 00001        38.118      1938928
# 00002        18.538      1488112
# 00003        18.326      1554512
# 00004        31.363      1720304
# 00005        69.989      3094224
# 00006        65.636      2879792
# 00007        17.789      1440352
# 00008        34.490      1866608
# 00009        40.111      2046072
# 00010        34.387      2278824
# 00011        34.639      2281400
# 00012        64.571      2825856
# 00013        36.498      1879304
# 00014        18.262      1554512
# 00015        33.612      2271288
# 00016        70.777      3108808
# 00017        33.982      2278824
# 00018        18.481      1539400
# 00019        38.216      1942672
# 00020        31.319      1720304
